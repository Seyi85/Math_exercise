# %%
import pandas as pd
import numpy as np

# %%
from urllib.request import urlretrieve
URL = 'http://go.gwu.edu/engcomp2data1'
urlretrieve(URL, 'beers.csv')
# Out:
# ('beers.csv', <http.client.HTTPMessage at 0x2185f4f0070>)

# %%
beers = pandas.read_csv("beers.csv")


type(beers)

beers
# Out:
#       Unnamed: 0    abv   ibu    id                  name  \
# 0              0  0.050   NaN  1436              Pub Beer
# 1              1  0.066   NaN  2265           Devil's Cup
# 2              2  0.071   NaN  2264   Rise of the Phoenix
# 3              3  0.090   NaN  2263              Sinister
# 4              4  0.075   NaN  2262         Sex and Candy
# ...          ...    ...   ...   ...                   ...
# 2405        2405  0.067  45.0   928             Belgorado
# 2406        2406  0.052   NaN   807         Rail Yard Ale
# 2407        2407  0.055   NaN   620       B3K Black Lager
# 2408        2408  0.055  40.0   145   Silverback Pale Ale
# 2409        2409  0.052   NaN    84  Rail Yard Ale (2009)
#
#                                style  brewery_id  ounces
# 0                American Pale Lager         408    12.0
# 1            American Pale Ale (APA)         177    12.0
# 2                       American IPA         177    12.0
# ...

# %%
DataFrame= pandas.read_csv("beers.csv")

data.head()
# Out:
#    Unnamed: 0    abv  ibu    id                 name  \
# 0           0  0.050  NaN  1436             Pub Beer
# 1           1  0.066  NaN  2265          Devil's Cup
# 2           2  0.071  NaN  2264  Rise of the Phoenix
# 3           3  0.090  NaN  2263             Sinister
# 4           4  0.075  NaN  2262        Sex and Candy
#
#                             style  brewery_id  ounces
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0

# %%
#to get the abv figures from the column

abv=DataFrame["abv"]
print(abv)
# Out:
# 0       0.050
# 1       0.066
# 2       0.071
# 3       0.090
# 4       0.075
#         ...
# 2405    0.067
# 2406    0.052
# 2407    0.055
# 2408    0.055
# 2409    0.052
# Name: abv, Length: 2410, dtype: float64

# %%
DataFrame.dropna()
# Out:
#       Unnamed: 0    abv   ibu    id                                  name  \
# 14            14  0.061  60.0  1979                          Bitter Bitch
# 21            21  0.099  92.0  1036                         Lower De Boom
# 22            22  0.079  45.0  1024                         Fireside Chat
# 24            24  0.044  42.0   876                       Bitter American
# 25            25  0.049  17.0   802  Hell or High Watermelon Wheat (2009)
# ...          ...    ...   ...   ...                                   ...
# 2398        2398  0.077  30.0  1513  Lights Out Vanilla Cream Extra Stout
# 2399        2399  0.069  69.0  1512                     Worthy IPA (2013)
# 2400        2400  0.060  50.0  1511                           Worthy Pale
# 2405        2405  0.067  45.0   928                             Belgorado
# 2408        2408  0.055  40.0   145                   Silverback Pale Ale
#
#                                style  brewery_id  ounces
# ...

# %%
ibu=DataFrame["ibu"]

print(ibu)

DataFrame.dropna(subset = ["ibu"])
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 2405    45.0
# 2406     NaN
# 2407     NaN
# 2408    40.0
# 2409     NaN
# Name: ibu, Length: 2410, dtype: float64
#       Unnamed: 0    abv   ibu    id                                  name  \
# 14            14  0.061  60.0  1979                          Bitter Bitch
# 21            21  0.099  92.0  1036                         Lower De Boom
# 22            22  0.079  45.0  1024                         Fireside Chat
# 24            24  0.044  42.0   876                       Bitter American
# 25            25  0.049  17.0   802  Hell or High Watermelon Wheat (2009)
# ...          ...    ...   ...   ...                                   ...
# 2398        2398  0.077  30.0  1513  Lights Out Vanilla Cream Extra Stout
# 2399        2399  0.069  69.0  1512                     Worthy IPA (2013)
# 2400        2400  0.060  50.0  1511                           Worthy Pale
# ...

# %%
ibu_series.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-6fe3cb5f948d> in <module>
# ----> 1 ibu_series.values
#
# NameError: name 'ibu_series' is not defined

# %%
#Missing values

mis_val = DataFrame.isnull().sum()
print(mis_val)
# Out:
# Unnamed: 0       0
# abv             62
# ibu           1005
# id               0
# name             0
# style            5
# brewery_id       0
# ounces           0
# dtype: int64

# %%
# % of missing values
mis_percent =100*DataFrame.isnull().sum()/ len(DataFrame)

print(mis_percent)
# Out:
# Unnamed: 0     0.000000
# abv            2.572614
# ibu           41.701245
# id             0.000000
# name           0.000000
# style          0.207469
# brewery_id     0.000000
# ounces         0.000000
# dtype: float64

# %%
abv_min = numpy.min(abv)
abv_max = numpy.max(abv)


print('The minimum value for abv is: ', abv_min)
print('The maximum value for abv is: ', abv_max)
# Out:
# The minimum value for abv is:  0.001
# The maximum value for abv is:  0.128

# %%
from matplotlib import pyplot
# %matplotlib inline


#You can set the size of the figure by doing:
pyplot.figure(figsize=(10,5))

#Plotting
pyplot.hist(abv, bins=15, color='r', histtype='bar', edgecolor='white') 
#The \n is to leave a blank line between the title and the plot
pyplot.title('abv \n')
pyplot.xlabel('Alcohol by Volume (abv) ')
pyplot.ylabel('Frequency');
